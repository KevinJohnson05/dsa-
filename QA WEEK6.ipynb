# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Find out how many countries are there in the dataset.

# %%
len(data.value_counts('country'))
# Out:
# 196

# %% [markdown]
# # Examine the data by using visualizations.

# %%
data.columns
# Out:
# Index(['country', 'Region', 'Surface area (km2)',
#        'Population in thousands (2017)', 'GDP per capita (current US$)',
#        'Agricultural production index ',
#        'International trade: Imports (million US$)'],
#       dtype='object')

# %%
d1=data[['country','GDP per capita (current US$)']]

# %%
f1=d1.nlargest(10,'GDP per capita (current US$)')

# %%
f1.plot(kind='bar',x='country',figsize=(17,8),title='TOP 10 GDP COUNTRIES')
plt.xticks(rotation=360);

# %%
d2=data[['Region', 'Agricultural production index ']]

# %%
f2=d2.nlargest(15,'Agricultural production index ')

# %%
f2.plot(kind='scatter',x='Region',y='Agricultural production index ',figsize=(15,8),s=100,title='REGION-WISE AGRICULTURAL PRODUCTION INDEX',color='red');

# %%
d3=data[['Surface area (km2)','Population in thousands (2017)']]

# %%
f3=d3.nlargest(5,'Population in thousands (2017)')

# %% [markdown]
# # 3.Find out how many countries with respect to the region are available in the dataset

# %%
data['Region'].value_counts()
# Out:
# WesternAsia          18
# EasternAfrica        17
# Caribbean            16
# WesternAfrica        15
# SouthAmerica         12
# SouthernEurope       12
# South-easternAsia    11
# EasternEurope        10
# NorthernEurope       10
# SouthernAsia          9
# MiddleAfrica          9
# CentralAmerica        8
# WesternEurope         7
# EasternAsia           7
# SouthernAfrica        5
# Polynesia             5
# NorthernAfrica        5
# Melanesia             5
# CentralAsia           5
# NorthernAmerica       4
# Micronesia            4
# Oceania               2
# Name: Region, dtype: int64

# %% [markdown]
# # 4. On average which region has the highest

# %% [markdown]
# a. GDP per capita (current US$)

# %%
high_dgp = data.groupby('Region')['GDP per capita (current US$)'].mean() 
high_dgp.nlargest(1)
# Out:
# Region
# NorthernAmerica    57659.0
# Name: GDP per capita (current US$), dtype: float64

# %% [markdown]
# b. International trade: Imports (million US$)

# %%
high_imports = data.groupby('Region')['International trade: Imports (million US$)'].mean() 
high_imports.nlargest(1)
# Out:
# Region
# NorthernAmerica    663552.25
# Name: International trade: Imports (million US$), dtype: float64

# %% [markdown]
# # 5. Find out which region has more consistent with respect to GDP per capita (current US$)

# %%
std1 = data.groupby('Region')['GDP per capita (current US$)'].std() 
print("Region has more consistent with respect to GDP percapita (current US$) is:")
std1.nsmallest(1)
# Out:
# Region has more consistent with respect to GDP percapita (current US$) is:
# Region
# WesternAfrica    815.095399
# Name: GDP per capita (current US$), dtype: float64
